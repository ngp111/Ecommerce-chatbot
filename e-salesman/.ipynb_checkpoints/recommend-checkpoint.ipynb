# %%
import pandas as pd
import json

# %%
oneplus = pd.read_csv("OneplusMobiles.csv")
redmi = pd.read_csv("RedmiMobiles.csv")
samsung = pd.read_csv("SamsungMobiles.csv")

# %%
oneplus.head(5)
# Out:
#   Category                                       Product name    Price  \
# 0   Mobile  OnePlus 8 5G UW (128GB, 8GB) 6.55" 90Hz AMOLED...  $519.99
# 1   Mobile  OnePlus 8T Lunar Silver, 5G Unlocked Android S...  $599.24
# 2   Mobile  OnePlus Nord N10 5G Unlocked Smartphone, Midni...  $299.99
# 3   Mobile  OnePlus Nord N10 5G (128GB, 6GB) 6.49", 90Hz R...  $324.90
# 4   Mobile  OnePlus 8 5G UW (128GB, 8GB) 6.55" 90Hz AMOLED...  $519.99
#
#                                          Product URL  \
# 0  https://www.amazon.com//gp/slredirect/picassoR...
# 1  https://www.amazon.com//OnePlus-Unlocked-Andro...
# 2  https://www.amazon.com//OnePlus-Unlocked-Smart...
# 3  https://www.amazon.com//OnePlus-Nord-N10-5G-In...
# 4  https://www.amazon.com//OnePlus-5G-UW-Snapdrag...
#
#                                     Product features             Ratings  \
# 0  {'Wireless Carrier': 'T-Mobile', 'Brand': 'One...  4.7 out of 5 stars
# 1  {'Wireless Carrier': 'Unlocked for All Carrier...  4.4 out of 5 stars
# 2  {'Wireless Carrier': 'Unlocked for All Carrier...  4.1 out of 5 stars
# 3  {'Wireless Carrier': 'Unlocked for All Carrier...  4.3 out of 5 stars
# 4  {'Wireless Carrier': 'T-Mobile', 'Brand': 'One...  4.3 out of 5 stars
#
#    Total reviews
# 0            9.0
# 1          377.0
# 2          114.0
# 3           40.0
# 4           10.0

# %%
dataset = oneplus.append(redmi)
dataset = dataset.append(samsung, sort="True", ignore_index=True)

# %%
dataset.head()
# Out:
#   Category    Price Product Ratings  \
# 0   Mobile  $519.99             NaN
# 1   Mobile  $599.24             NaN
# 2   Mobile  $299.99             NaN
# 3   Mobile  $324.90             NaN
# 4   Mobile  $519.99             NaN
#
#                                          Product URL  \
# 0  https://www.amazon.com//gp/slredirect/picassoR...
# 1  https://www.amazon.com//OnePlus-Unlocked-Andro...
# 2  https://www.amazon.com//OnePlus-Unlocked-Smart...
# 3  https://www.amazon.com//OnePlus-Nord-N10-5G-In...
# 4  https://www.amazon.com//OnePlus-5G-UW-Snapdrag...
#
#                                     Product features  \
# 0  {'Wireless Carrier': 'T-Mobile', 'Brand': 'One...
# 1  {'Wireless Carrier': 'Unlocked for All Carrier...
# 2  {'Wireless Carrier': 'Unlocked for All Carrier...
# 3  {'Wireless Carrier': 'Unlocked for All Carrier...
# 4  {'Wireless Carrier': 'T-Mobile', 'Brand': 'One...
#
#                                         Product name             Ratings  \
# 0  OnePlus 8 5G UW (128GB, 8GB) 6.55" 90Hz AMOLED...  4.7 out of 5 stars
# 1  OnePlus 8T Lunar Silver, 5G Unlocked Android S...  4.4 out of 5 stars
# 2  OnePlus Nord N10 5G Unlocked Smartphone, Midni...  4.1 out of 5 stars
# 3  OnePlus Nord N10 5G (128GB, 6GB) 6.49", 90Hz R...  4.3 out of 5 stars
# 4  OnePlus 8 5G UW (128GB, 8GB) 6.55" 90Hz AMOLED...  4.3 out of 5 stars
#
#    Total reviews
# 0            9.0
# 1          377.0
# 2          114.0
# 3           40.0
# 4           10.0

# %%
len(dataset)
# Out:
# 490

# %%
features = dataset["Product features"]

# %%
summary = {}
for i in range(len(features)) :
    features[i] = features[i].replace("'", '"')
    features[i] = json.loads(features[i])
    for name, value in features[i].items() :
        if name not in summary :
            summary[name] = set()
            summary[name].add(value.strip())
        else :
            summary[name].add(value)
# Out:
# /home/intel123/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/intel123/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
dataset["Product features"] = features

# %%
prices = dataset["Price"]
prices = [prices[i].replace("$", "") for i in range(len(prices))]
prices = [prices[i].replace(",", "") for i in range(len(prices))]
prices = [float(prices[i]) for i in range(len(prices))]
dataset["Price"] = prices

# %%
dataset["Price"].describe()
# Out:
# count     490.000000
# mean      356.769082
# std       270.761241
# min         7.990000
# 25%       149.990000
# 50%       217.500000
# 75%       599.435000
# max      1069.000000
# Name: Price, dtype: float64

# %%
dataset.to_csv("Mobiles.csv")

# %%
print(summary.keys())
# Out:
# dict_keys(['Wireless Carrier', 'Brand', 'Color', 'Memory Storage Capacity', 'Manufacturer', 'Product Dimensions', 'Item Weight', 'ASIN', 'Item model number', 'Batteries', 'Customer Reviews', 'Best Sellers Rank', 'Other display features', 'Colour', 'Date First Available', 'Operating System', 'Screen Size', 'Display Type', 'Cellular Technology', 'Form Factor', 'Package Dimensions', 'OS', 'RAM', 'Special Features', 'Included Components', 'Other camera features', 'Connectivity technologies', 'GPS', 'Device interface - primary', 'Audio Jack', 'Battery Power Rating', 'Phone Talk Time', 'Phone Standy Time (with data)', 'Connectivity Technology', 'Wireless communication technologies', 'Display technology', 'Is Discontinued By Manufacturer', 'Scanner Resolution', 'Material', 'Compatible Phone Models', 'Connector Type', 'Shooting Modes', 'Rear Camera Resolution', 'Model Name', 'Supported Application', 'Water Resistance Level', 'Battery Life', 'Battery Cell Composition', 'Domestic Shipping', 'International Shipping'])

# %%
missing = {}
color = []
for prop in summary.keys() :
    if prop == "Colour" :
        continue
    missing[prop] = 0
    for i in range(len(features)) :
        if prop not in features[i].keys() :
            if prop == "Color" :
                if "Colour" not in features[i].keys() :
                    color.append()
                    missing[prop] += 1
            else :
                missing[prop] += 1
{k: v for k, v in sorted(missing.items(), key=lambda item: item[1])}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-6e16673ae446> in <module>
#       9             if prop == "Color" :
#      10                 if "Colour" not in features[i].keys() :
# ---> 11                     color += 1
#      12                     missing[prop] += 1
#      13             else :
#
# TypeError: 'int' object is not iterable

# %%
def is_color(index, color) :
    if "Color" in dataset.iloc[index]["Product features"].keys() :
        if(color.lower() not in dataset.iloc[index]["Product features"]["Color"].lower()) :
            return False
    elif "Colour" in dataset.iloc[index]["Product features"].keys() :
        if(color.lower() not in dataset.iloc[index]["Product features"]["Colour"].lower()) :
            return False
    elif color.lower() not in dataset.iloc[index]["Product name"].lower() :
        return False
    return True

# %%
def is_memory(index, memory) :
    if "Memory Storage Capacity" in dataset.iloc[index]["Product features"].keys() :
        if(memory != dataset.iloc[index]["Product features"]["Memory Storage Capacity"]) :
            return False
    elif "gb" in dataset.iloc[index]["Product name"].lower() :
        value, gb = memory.split()
        if value not in dataset.iloc[index]["Product name"] :
            return False
    return True

# %%
def recommend(color, memory, name) :
    non_potential = set()
    potential = set(range(len(dataset)))
    for index in potential :
        if(not is_memory(index, memory)) :
            non_potential.add(index)
    potential = potential-non_potential
    return potential

# %%
potential = list(recommend("Pink", "6 GB", "Oppo"))
print(potential)
# Out:
# [12, 14, 15, 16, 29, 31, 32, 33, 35, 39, 44, 47, 49, 50, 52, 53, 54, 56, 60, 65, 68, 70, 71, 73, 74, 75, 87, 104, 105, 106, 108]

# %%
print(dataset.iloc[0]["Product features"])
# Out:
# {'Wireless Carrier': 'T-Mobile', 'Brand': 'OnePlus', 'Color': 'Polar Silver', 'Memory Storage Capacity': '128 GB', 'Manufacturer': 'OnePlus', 'Product Dimensions': '6 x 4 x 2 inches', 'Item Weight': '1.46 pounds', 'ASIN': 'B08R6H1RN9', 'Item model number': 'OnePlus 8 5G UW', 'Batteries': '1 Lithium ion batteries required. (included)', 'Customer Reviews': '4.7 out of 5 stars\n\n\n\n\n\n\n\n\n9 ratings\n\n\n\n\n\n\n4.7 out of 5 stars', 'Best Sellers Rank': '#36,198 in Cell Phones & Accessories (See Top 100 in Cell Phones & Accessories)\n\n#30,011 in Cell Phone Accessories', 'Other display features': 'CE', 'Colour': 'Polar Silver', 'Date First Available': 'January 1, 2020'}

# %%
def is_color(index, color) :
    #print("In is_color")
    if "Color" in dataset.iloc[index]["Product features"].keys() :
        if(color.lower() not in dataset.iloc[index]["Product features"]["Color"].lower()) :
            return False
    elif "Colour" in dataset.iloc[index]["Product features"].keys() :
        if(color.lower() not in dataset.iloc[index]["Product features"]["Colour"].lower()) :
            return False
    elif color.lower() not in dataset.iloc[index]["Product name"].lower() :
        return False
    return True
    
def is_brand(index, brand) :
   # print("In is_brand")
    if brand.lower() not in dataset.iloc[index]["Product name"].lower() :
        return False
    #print("Out of is_brand")
    return True
    
def is_os(index, os) :
    #print("In is_os")
    if "OS" in dataset.iloc[index]["Product features"].keys() :
        if(os.lower() not in dataset.iloc[index]["Product features"]["OS"].lower()) :
            return False
    elif os.lower() in dataset.iloc[index]["Product name"].lower() :
        return True
    elif "android" in os.lower() :
        return True
    else :
        return False

def recommend_mobile(color, os, brand) :
    non_potential = set()
    potential = set(range(len(dataset)))
    print("Checking brand")
    for index in potential :
        if(not is_brand(index, brand)) :
            non_potential.add(index)
    
    potential1 = potential-non_potential
    print("Checking os")
    non_potential = set()
    for index in potential1 :
        if(not is_os(index, os)) :
            non_potential.add(index)
    potential2 = potential1-non_potential
    print("Checking color")
    non_potential = set()
    for index in potential2 :
        if(not is_color(index, color)) :
            non_potential.add(index)
    potential3 = potential2-non_potential
    if(potential3) :
        return potential3
    elif(potential2) :
        print("No color match")
        return potential2
    elif(potential1) :
        print("No os match")
        return potential1
    else :
        print("No brand match")
        return potential3

# %%
potential = recommend_mobile("silver", "android", "samsung")
# Out:
# Checking brand
# Checking os
# Checking color

# %%
for index in potential :
    print(dataset.iloc[index]["Product name"])
# Out:
# Samsung Galaxy S21 Ultra 5G | Factory Unlocked Android Cell Phone | US Version 5G Smartphone | Pro-Grade Camera, 8K Video, 108MP High Res | 128GB, Phantom Silver (SM-G998UZSAXAA)
# Samsung Galaxy S21 Ultra 5G | Factory Unlocked Android Cell Phone | US Version 5G Smartphone | Pro-Grade Camera, 8K Video, 108MP High Res | 128GB, Phantom Silver (SM-G998UZSAXAA)
# Samsung Galaxy S21 Ultra 5G | Factory Unlocked Android Cell Phone | US Version 5G Smartphone | Pro-Grade Camera, 8K Video, 108MP High Res | 128GB, Phantom Silver (SM-G998UZSAXAA)

# %%
for i in range(10) :
    print(samsung.iloc[i]["Product name"], samsung.iloc[i]["Product features"])
# Out:
# Samsung Galaxy S21 5G | Factory Unlocked Android Cell Phone | US Version 5G Smartphone | Pro-Grade Camera, 8K Video, 64MP High Res | 256GB, Phantom Gray (SM-G991UZAEXAA) {'Wireless Carrier': 'Unlocked for All Carriers', 'Brand': 'Samsung Electronics', 'Color': 'Phantom Gray', 'Memory Storage Capacity': '256 GB', 'Operating System': 'Android', 'Screen Size': '6.2 Inches', 'Display Type': 'AMOLED', 'Cellular Technology': '5G', 'Manufacturer': 'Samsung', 'Other camera features': 'Rear, Front', 'Product Dimensions': '6.7 x 3.4 x 2.44 inches', 'Item Weight': '5 ounces', 'ASIN': 'B08N38M7NT', 'Item model number': 'SM-G991UZAEXAA', 'Batteries': '1 Lithium ion batteries required. (included)', 'Customer Reviews': '5.0 out of 5 stars\n\n\n\n\n\n\n\n\n24 ratings\n\n\n\n\n\n\n5.0 out of 5 stars', 'Best Sellers Rank': '#2,547 in Electronics (See Top 100 in Electronics)\n\n#96 in Cell Phones', 'Date First Available': 'January 14, 2021'}
# Samsung Galaxy S20 FE 5G | Factory Unlocked Android Cell Phone | 128 GB | US Version Smartphone | Pro-Grade Camera, 30X Space Zoom, Night Mode | Cloud Red {'Product Dimensions': '6.7 x 3.4 x 2.44 inches', 'Item Weight': '6.7 ounces', 'ASIN': 'B08FYV84JT', 'Item model number': 'SM-G781UZRMXAA', 'Batteries': '1 Lithium ion batteries required. (included)', 'Customer Reviews': '4.6 out of 5 stars\n\n\n\n\n\n\n\n\n3,693 ratings\n\n\n\n\n\n\n4.6 out of 5 stars', 'Best Sellers Rank': '#1,415 in Electronics (See Top 100 in Electronics)\n\n#47 in Cell Phones', 'OS': 'Android', 'RAM': '6 GB', 'Wireless communication technologies': 'Bluetooth, 4G, 3G, Wi-Fi', 'Connectivity technologies': 'Wireless, Bluetooth', 'Other display features': 'Wireless', 'Device interface - primary': 'Touchscreen', 'Other camera features': 'Front, Rear, Video', 'Form Factor': 'Smartphone', 'Colour': 'Cloud Red', 'Battery Power Rating': '16', 'Included Components': 'Travel Adapter, Handset, Data Cable, Ejection Pin', 'Manufacturer': 'Samsung', 'Date First Available': 'September 23, 2020'}
# Samsung Galaxy S21 Ultra 5G | Factory Unlocked Android Cell Phone | US Version 5G Smartphone | Pro-Grade Camera, 8K Video, 108MP High Res | 128GB, Phantom Silver (SM-G998UZSAXAA) {'Wireless Carrier': 'Unlocked for All Carriers', 'Brand': 'Samsung Electronics', 'Color': 'Phantom Silver', 'Memory Storage Capacity': '128 GB', 'Operating System': 'Android', 'Screen Size': '6.8 Inches', 'Display Type': 'AMOLED', 'Cellular Technology': '5G', 'Manufacturer': 'Samsung', 'Other camera features': 'Rear, Front', 'Product Dimensions': '7.3 x 3.7 x 2.6 inches', 'Item Weight': '8.1 ounces', 'ASIN': 'B08N3BYNDN', 'Item model number': 'SM-G998UZSAXAA', 'Batteries': '1 Lithium ion batteries required. (included)', 'Customer Reviews': '4.6 out of 5 stars\n\n\n\n\n\n\n\n\n92 ratings\n\n\n\n\n\n\n4.6 out of 5 stars', 'Best Sellers Rank': '#823 in Electronics (See Top 100 in Electronics)\n\n#21 in Cell Phones', 'Date First Available': 'January 14, 2021'}
# Samsung Galaxy A10S A107M 32GB Unlocked GSM DUOS Phone w/ Dual 13MP & 2MP Camera (International Variant/US Compatible LTE) – Black {'Brand': 'SAMSUNG', 'Color': 'Black', 'Memory Storage Capacity': '32 GB', 'Operating System': 'Android', 'Screen Size': '6.2 Inches', 'Display Type': 'LCD', 'Cellular Technology': '2G', 'Manufacturer': 'Samsung', 'Other camera features': 'Rear, Front', 'Form Factor': 'Smartphone', 'Item Weight': '10.8 ounces', 'ASIN': 'B07XQJ33PL', 'Item model number': 'A107M', 'Batteries': '1 Lithium Polymer batteries required. (included)', 'Customer Reviews': '4.3 out of 5 stars\n\n\n\n\n\n\n\n\n7,886 ratings\n\n\n\n\n\n\n4.3 out of 5 stars', 'Best Sellers Rank': '#687 in Electronics (See Top 100 in Electronics)\n\n#19 in Cell Phones', 'Is Discontinued By Manufacturer': 'No', 'OS': 'Android', 'Wireless communication technologies': 'Cellular', 'Special Features': 'Dual SIM, 4G LTE', 'Other display features': 'Wireless', 'Device interface - primary': 'Touchscreen', 'Scanner Resolution': '720 x 1520', 'Colour': 'Black', 'Date First Available': 'September 10, 2019'}
# Samsung Galaxy S20 FE 5G | Factory Unlocked Android Cell Phone | 128 GB | US Version Smartphone | Pro-Grade Camera, 30X Space Zoom, Night Mode | Cloud Lavender {'Wireless Carrier': 'VoiceStream Wireless Provider Type', 'Brand': 'Samsung Electronics', 'Color': 'Cloud Lavender', 'Memory Storage Capacity': '128 GB', 'Operating System': 'Android', 'Screen Size': '6.5 Inches', 'Display Type': 'AMOLED', 'Cellular Technology': '5G', 'Manufacturer': 'Samsung', 'Other camera features': 'Front, Rear, Video', 'Product Dimensions': '0.33 x 2.93 x 6.29 inches', 'Item Weight': '6.7 ounces', 'ASIN': 'B08FYTRF6J', 'Item model number': 'SM-G781ULVMXAA', 'Batteries': '1 Lithium ion batteries required. (included)', 'Customer Reviews': '4.6 out of 5 stars\n\n\n\n\n\n\n\n\n3,693 ratings\n\n\n\n\n\n\n4.6 out of 5 stars', 'Best Sellers Rank': '#1,916 in Electronics (See Top 100 in Electronics)\n\n#64 in Cell Phones', 'OS': 'Android', 'RAM': '8 GB', 'Wireless communication technologies': 'Bluetooth, 4G, 3G, Wi-Fi', 'Connectivity technologies': 'Wireless, Bluetooth', 'Other display features': 'Wireless', 'Device interface - primary': 'Touchscreen', 'Form Factor': 'Smartphone', 'Colour': 'Cloud Lavender', 'Battery Power Rating': '16', 'Included Components': 'Travel Adapter, Handset, Data Cable, Ejection Pin', 'Date First Available': 'September 23, 2020'}
# Samsung Galaxy A51 A515F 128GB DUOS GSM Unlocked Phone w/Quad Camera 48 MP + 12 MP + 5 MP + 5 MP (International Variant/US Compatible LTE) - Prism Crush Blue {'Brand': 'Samsung Electronics', 'Color': 'Blue', 'Memory Storage Capacity': '128 GB', 'Operating System': 'Android', 'Screen Size': '6.5 Inches', 'Display Type': 'AMOLED', 'Cellular Technology': '4G', 'Manufacturer': 'Samsung', 'Other camera features': 'Rear, Front', 'Connectivity Technology': 'Bluetooth, Wi-Fi', 'Product Dimensions': '7 x 3 x 2.5 inches', 'Item Weight': '6.1 ounces', 'ASIN': 'B082YF7WY5', 'Item model number': 'SM-A515F/DS', 'Batteries': '1 Lithium Polymer batteries required. (included)', 'Customer Reviews': '4.4 out of 5 stars\n\n\n\n\n\n\n\n\n2,099 ratings\n\n\n\n\n\n\n4.4 out of 5 stars', 'Best Sellers Rank': '#1,949 in Electronics (See Top 100 in Electronics)\n\n#66 in Cell Phones', 'Date First Available': 'December 20, 2019'}
# Samsung Electronics Galaxy Note 20 5G Factory Unlocked Android Cell Phone, US Version, 128GB of Storage, Mobile Gaming Smartphone, Long-Lasting Battery, Mystic Bronze, SM-N981UZNAXAA {'Product Dimensions': '0.33 x 6.36 x 2.96 inches', 'Item Weight': '6.7 ounces', 'ASIN': 'B08BX8BZ1P', 'Item model number': 'SM-N981UZNAXAA', 'Batteries': '1 Lithium ion batteries required. (included)', 'Customer Reviews': '4.6 out of 5 stars\n\n\n\n\n\n\n\n\n3,466 ratings\n\n\n\n\n\n\n4.6 out of 5 stars', 'Best Sellers Rank': '#3,257 in Electronics (See Top 100 in Electronics)\n\n#126 in Cell Phones', 'OS': 'Android 10.0', 'RAM': '8 GB', 'Wireless communication technologies': 'Cellular', 'Other display features': 'Wireless', 'Device interface - primary': 'Touchscreen with Stylus Support', 'Other camera features': 'Rear, Front', 'Form Factor': 'Smartphone', 'Colour': 'Mystic Bronze', 'Included Components': 'Travel adapter, Data cable, Ejection Pin, Quick Reference Manual, Terms & Condtions, Health & Safety Guide', 'Manufacturer': 'Samsung', 'Date First Available': 'August 6, 2020'}
# Samsung Galaxy A12 (A125M) 64GB Dual SIM, GSM Unlocked, (CDMA Verizon/Sprint Not Supported) Smartphone Latin American Version No Warranty (Blue) {'Brand': 'SAMSUNG', 'Color': 'Blue', 'Memory Storage Capacity': '64 GB', 'Operating System': 'Android', 'Screen Size': '6.5 Inches', 'Display Type': 'LCD', 'Cellular Technology': '4G', 'Manufacturer': 'Samsung', 'Other camera features': 'Rear, Front', 'Connectivity Technology': 'Bluetooth', 'Product Dimensions': '6 x 4 x 2 inches', 'Item Weight': '12 ounces', 'ASIN': 'B08SBZCW7S', 'Item model number': 'A125M/DS', 'Batteries': '1 Lithium Polymer batteries required. (included)', 'Customer Reviews': '4.0 out of 5 stars\n\n\n\n\n\n\n\n\n11 ratings\n\n\n\n\n\n\n4.0 out of 5 stars', 'Best Sellers Rank': '#4,352 in Electronics (See Top 100 in Electronics)\n\n#179 in Cell Phones', 'Is Discontinued By Manufacturer': 'No', 'OS': 'Android', 'RAM': '4 GB', 'Wireless communication technologies': 'Cellular', 'Connectivity technologies': 'Bluetooth', 'Display technology': 'LCD', 'Other display features': 'Wireless', 'Form Factor': 'Smartphone', 'Colour': 'Blue', 'Date First Available': 'January 7, 2021'}
# Samsung Galaxy A21S SM-A217M/DS 4G LTE 64GB + 4GB Ram LTE USA w/Four Cameras (48+8+2+2mp) Android International Version (GSM Only, Not CDMA) (White) {'Brand': 'Samsung Electronics', 'Color': 'White', 'Memory Storage Capacity': '64 GB', 'Screen Size': '6.5 Inches', 'Display Type': 'LCD', 'Cellular Technology': '4G', 'Manufacturer': 'Samsung', 'Other camera features': 'Front', 'Form Factor': 'Smartphone', 'Item Weight': '7 ounces', 'Product Dimensions': '15.99 x 8.99 x 1 inches', 'ASIN': 'B089XZ2R8D', 'Item model number': 'SM-A217M/DS', 'Batteries': '1 Lithium Polymer batteries required.', 'Customer Reviews': '4.5 out of 5 stars\n\n\n\n\n\n\n\n\n1,349 ratings\n\n\n\n\n\n\n4.5 out of 5 stars', 'Best Sellers Rank': '#6,399 in Electronics (See Top 100 in Electronics)\n\n#268 in Cell Phones', 'Is Discontinued By Manufacturer': 'Yes', 'Wireless communication technologies': 'Cellular', 'Display technology': 'LCD', 'Other display features': 'Wireless', 'Device interface - primary': 'Touchscreen', 'Scanner Resolution': '1280 x 720', 'Audio Jack': '3.5 mm', 'Colour': 'White', 'Date First Available': 'June 9, 2020'}
# Samsung Galaxy A02s A025M 64GB Dual Sim GSM Unlocked Android Smart Phone - Red {'Wireless Carrier': 'AT&T', 'Brand': 'SAMSUNG', 'Color': 'Red', 'Memory Storage Capacity': '64 GB', 'Operating System': 'Android', 'Screen Size': '6.5 Inches', 'Display Type': 'LCD', 'Cellular Technology': '2G', 'Manufacturer': 'Samsung', 'Other camera features': 'Front', 'Product Dimensions': '5.91 x 3.15 x 0.36 inches', 'Item Weight': '12.3 ounces', 'ASIN': 'B08SBFC1ZZ', 'Item model number': 'A025M/DS', 'Batteries': '1 Lithium ion batteries required. (included)', 'Customer Reviews': '4.3 out of 5 stars\n\n\n\n\n\n\n\n\n13 ratings\n\n\n\n\n\n\n4.3 out of 5 stars', 'Best Sellers Rank': '#8,344 in Electronics (See Top 100 in Electronics)\n\n#343 in Cell Phones', 'Is Discontinued By Manufacturer': 'No', 'OS': 'Android', 'RAM': '4 GB', 'Wireless communication technologies': 'Cellular', 'Connectivity technologies': 'Wi-Fi', 'Display technology': 'LCD', 'Other display features': 'Wireless', 'Device interface - primary': 'Touchscreen', 'Form Factor': 'Smartphone', 'Colour': 'Red', 'Date First Available': 'January 7, 2021'}

# %%
"samsung" and "red" in "Samsung black".lower()
# Out:
# False

# %%
import csv
with open("SamsungMobiles.csv") as f_obj :
    reader = csv.reader(f_obj, delimiter=",")
    for line in reader :
        if color.lower()
# Out:
# Category
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones
# Phones

# %%
import numpy as np
from sklearn.decomposition import PCA
from typing import List

# %%
class Word:
    def __init__(self, text, vector):
        self.text = text
        self.vector = vector

    def __str__(self):
        return self.text + ' : ' + str(self.vector)

    def __repr__(self):
        return self.__str__()

# %%
class Sentence:
    def __init__(self, word_list):
        self.word_list = word_list

    # return the length of a sentence
    def len(self) -> int:
        return len(self.word_list)

    def __str__(self):
        word_str_list = [word.text for word in self.word_list]
        return ' '.join(word_str_list)

    def __repr__(self):
        return self.__str__()

# %%
def get_word_frequency(word_text):
    return 0.0001

# %%
def sentence_to_vec(sentence_list: List[Sentence], embedding_size: int, a: float=1e-3):
    sentence_set = []
    for sentence in sentence_list:
        vs = np.zeros(embedding_size)  # add all word2vec values into one vector for the sentence
        sentence_length = sentence.len()
        for word in sentence.word_list:
            a_value = a / (a + get_word_frequency(word.text))  # smooth inverse frequency, SIF
            vs = np.add(vs, np.multiply(a_value, word.vector))  # vs += sif * word_vector

        vs = np.divide(vs, sentence_length)  # weighted average
        sentence_set.append(vs)  # add to our existing re-calculated set of sentences

    # calculate PCA of this sentence set
    pca = PCA()
    pca.fit(np.array(sentence_set))
    u = pca.components_[0]  # the PCA vector
    u = np.multiply(u, np.transpose(u))  # u x uT

    # pad the vector?  (occurs if we have less sentences than embeddings_size)
    if len(u) < embedding_size:
        for i in range(embedding_size - len(u)):
            u = np.append(u, 0)  # add needed extension for multiplication below

    # resulting sentence vectors, vs = vs -u x uT x vs
    sentence_vecs = []
    for vs in sentence_set:
        sub = np.multiply(u,vs)
        sentence_vecs.append(np.subtract(vs, sub))

    return sentence_vecs

# %%
import spacy
import math

# %%
nlp = spacy.load('en_core_web_lg')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-12-ceb8f64bba80> in <module>
# ----> 1 nlp = spacy.load('en_core_web_lg')
#
# ~/anaconda3/lib/python3.7/site-packages/spacy/__init__.py in load(name, **overrides)
#      25     if depr_path not in (True, False, None):
#      26         deprecation_warning(Warnings.W001.format(path=depr_path))
# ---> 27     return util.load_model(name, **overrides)
#      28
#      29
#
# ~/anaconda3/lib/python3.7/site-packages/spacy/util.py in load_model(name, **overrides)
#     169     elif hasattr(name, "exists"):  # Path or Path-like to model data
#     170         return load_model_from_path(name, **overrides)
# --> 171     raise IOError(Errors.E050.format(name=name))
#     172
#     173
#
# OSError: [E050] Can't find model 'en_core_web_lg'. It doesn't seem to be a shortcut link, a Python package or a valid path to a data directory.

# %%
pip install spacy
# Out:
# Requirement already satisfied: spacy in /home/intel123/anaconda3/lib/python3.7/site-packages (2.2.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/intel123/anaconda3/lib/python3.7/site-packages (from spacy) (2.0.3)
# Requirement already satisfied: numpy>=1.15.0 in /home/intel123/anaconda3/lib/python3.7/site-packages (from spacy) (1.16.4)
# Requirement already satisfied: srsly<1.1.0,>=0.1.0 in /home/intel123/anaconda3/lib/python3.7/site-packages (from spacy) (1.0.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/intel123/anaconda3/lib/python3.7/site-packages (from spacy) (1.0.0)
# Requirement already satisfied: thinc<7.2.0,>=7.1.1 in /home/intel123/anaconda3/lib/python3.7/site-packages (from spacy) (7.1.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/intel123/anaconda3/lib/python3.7/site-packages (from spacy) (3.0.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.2.0 in /home/intel123/anaconda3/lib/python3.7/site-packages (from spacy) (0.6.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /home/intel123/anaconda3/lib/python3.7/site-packages (from spacy) (0.4.1)
# Requirement already satisfied: plac<1.0.0,>=0.9.6 in /home/intel123/anaconda3/lib/python3.7/site-packages (from spacy) (0.9.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/intel123/anaconda3/lib/python3.7/site-packages (from spacy) (2.22.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/intel123/anaconda3/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2019.6.16)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/intel123/anaconda3/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/intel123/anaconda3/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.2)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/intel123/anaconda3/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.8)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in /home/intel123/anaconda3/lib/python3.7/site-packages (from thinc<7.2.0,>=7.1.1->spacy) (4.32.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !spacy download en_core_web_lg
# Out:
# /home/intel123/chatbot/e-salesman/env/bin/python: No module named spacy
